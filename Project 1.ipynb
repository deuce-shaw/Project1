# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
employee_attrition = pd.read_csv("HR_Analytics.csv.csv")
employee_attrition.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df = pd.DataFrame(employee_attrition)
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
job_role = df.groupby(['JobRole']).nunique()
job_role
# Out:
#                            Age  Attrition  BusinessTravel  DailyRate  \
# JobRole
# Healthcare Representative   35          2               3        125
# Human Resources             24          2               3         51
# Laboratory Technician       40          2               3        242
# Manager                     28          2               3         98
# Manufacturing Director      36          2               3        138
# Research Director           27          2               3         80
# Research Scientist          40          2               3        261
# Sales Executive             36          2               3        292
# Sales Representative        28          2               3         81
#
#                            Department  DistanceFromHome  Education  \
# JobRole
# Healthcare Representative           1                27          5
# Human Resources                     1                20          5
# ...

# %%
manager_single = len(df[(df['JobRole']=='Manager') & (df['MaritalStatus']=='Single')])
manager_married = len(df[(df['JobRole']=='Manager') & (df['MaritalStatus']=='Married')])
manager_divorced = len(df[(df['JobRole']=='Manager') & (df['MaritalStatus']=='Divorced')])

manager_single_stay = len(df[(df['JobRole']=='Manager') & (df['MaritalStatus']=='Single') & (df['Attrition']=='No')])
manager_married_stay = len(df[(df['JobRole']=='Manager') & (df['MaritalStatus']=='Married') & (df['Attrition']=='No')])
manager_divorced_stay = len(df[(df['JobRole']=='Manager') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='No')])

manager_single_leave = len(df[(df['JobRole']=='Manager') & (df['MaritalStatus']=='Single') & (df['Attrition']=='Yes')])
manager_married_leave = len(df[(df['JobRole']=='Manager') & (df['MaritalStatus']=='Married') & (df['Attrition']=='Yes')])
manager_divorced_leave = len(df[(df['JobRole']=='Manager') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='Yes')])

manager_stay = len(df[(df['JobRole']=='Manager') & (df['Attrition']=='No')])
manager_leave = len(df[(df['JobRole']=='Manager') & (df['Attrition']=='Yes')])
manager_total = len(df[(df['JobRole']=='Manager')])


print(manager_single, manager_married, manager_divorced) 
print(manager_single_stay, manager_married_stay, manager_divorced_stay)
print(manager_single_leave, manager_married_leave, manager_divorced_leave)
print(manager_stay, manager_leave, manager_total)
# Out:
# 23 56 23
# 22 52 23
# 1 4 0
# 97 5 102

# %%
healthcarerep_single = len(df[(df['JobRole']=='Healthcare Representative') & (df['MaritalStatus']=='Single')])
healthcarerep_married = len(df[(df['JobRole']=='Healthcare Representative') & (df['MaritalStatus']=='Married')])
healthcarerep_divorced = len(df[(df['JobRole']=='Healthcare Representative') & (df['MaritalStatus']=='Divorced')])

healthcarerep_single_stay = len(df[(df['JobRole']=='Healthcare Representative') & (df['MaritalStatus']=='Single') & (df['Attrition']=='No')])
healthcarerep_married_stay = len(df[(df['JobRole']=='Healthcare Representative') & (df['MaritalStatus']=='Married') & (df['Attrition']=='No')])
healthcarerep_divorced_stay = len(df[(df['JobRole']=='Healthcare Representative') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='No')])

healthcarerep_single_leave = len(df[(df['JobRole']=='Healthcare Representative') & (df['MaritalStatus']=='Single') & (df['Attrition']=='Yes')])
healthcarerep_married_leave = len(df[(df['JobRole']=='Healthcare Representative') & (df['MaritalStatus']=='Married') & (df['Attrition']=='Yes')])
healthcarerep_divorced_leave = len(df[(df['JobRole']=='Healthcare Representative') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='Yes')])

healthcarerep_stay = len(df[(df['JobRole']=='Healthcare Representative') & (df['Attrition']=='No')])
healthcarerep_leave = len(df[(df['JobRole']=='Healthcare Representative') & (df['Attrition']=='Yes')])
healthcarerep_total = len(df[(df['JobRole']=='Healthcare Representative')])


print(healthcarerep_single, healthcarerep_married, healthcarerep_divorced)
print(healthcarerep_single_stay, healthcarerep_married_stay, healthcarerep_divorced_stay)
print(healthcarerep_single_leave, healthcarerep_married_leave, healthcarerep_divorced_leave)
print(healthcarerep_stay, healthcarerep_leave, healthcarerep_total)
# Out:
# 36 61 34
# 34 55 33
# 2 6 1
# 122 9 131

# %%
hr_single = len(df[(df['JobRole']=='Human Resources') & (df['MaritalStatus']=='Single')])
hr_married = len(df[(df['JobRole']=='Human Resources') & (df['MaritalStatus']=='Married')])
hr_divorced = len(df[(df['JobRole']=='Human Resources') & (df['MaritalStatus']=='Divorced')])

hr_single_stay = len(df[(df['JobRole']=='Human Resources') & (df['MaritalStatus']=='Single') & (df['Attrition']=='No')])
hr_married_stay = len(df[(df['JobRole']=='Human Resources') & (df['MaritalStatus']=='Married') & (df['Attrition']=='No')])
hr_divorced_stay = len(df[(df['JobRole']=='Human Resources') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='No')])

hr_single_leave = len(df[(df['JobRole']=='Human Resources') & (df['MaritalStatus']=='Single') & (df['Attrition']=='Yes')])
hr_married_leave = len(df[(df['JobRole']=='Human Resources') & (df['MaritalStatus']=='Married') & (df['Attrition']=='Yes')])
hr_divorced_leave = len(df[(df['JobRole']=='Human Resources') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='Yes')])

hr_stay = len(df[(df['JobRole']=='Human Resources') & (df['Attrition']=='No')])
hr_leave = len(df[(df['JobRole']=='Human Resources') & (df['Attrition']=='Yes')])
hr_total = len(df[(df['JobRole']=='Human Resources')])


print(hr_single, hr_married, hr_divorced)
print(hr_single_stay, hr_married_stay, hr_divorced_stay)
print(hr_single_leave, hr_married_leave, hr_divorced_leave)
print(hr_stay, hr_leave, hr_total)
# Out:
# 10 28 14
# 9 22 9
# 1 6 5
# 40 12 52

# %%
labtech_single = len(df[(df['JobRole']=='Laboratory Technician') & (df['MaritalStatus']=='Single')])
labtech_married = len(df[(df['JobRole']=='Laboratory Technician') & (df['MaritalStatus']=='Married')])
labtech_divorced= len(df[(df['JobRole']=='Laboratory Technician') & (df['MaritalStatus']=='Divorced')])

labtech_single_stay = len(df[(df['JobRole']=='Laboratory Technician') & (df['MaritalStatus']=='Single') & (df['Attrition']=='No')])
labtech_married_stay = len(df[(df['JobRole']=='Laboratory Technician') & (df['MaritalStatus']=='Married') & (df['Attrition']=='No')])
labtech_divorced_stay= len(df[(df['JobRole']=='Laboratory Technician') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='No')])

labtech_single_leave = len(df[(df['JobRole']=='Laboratory Technician') & (df['MaritalStatus']=='Single') & (df['Attrition']=='Yes')])
labtech_married_leave = len(df[(df['JobRole']=='Laboratory Technician') & (df['MaritalStatus']=='Married') & (df['Attrition']=='Yes')])
labtech_divorced_leave= len(df[(df['JobRole']=='Laboratory Technician') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='Yes')])


labtech_stay = len(df[(df['JobRole']=='Laboratory Technician') & (df['Attrition']=='No')])
labtech_leave = len(df[(df['JobRole']=='Laboratory Technician') & (df['Attrition']=='Yes')])
labtech_total = len(df[(df['JobRole']=='Laboratory Technician')])

print(labtech_single, labtech_married, labtech_divorced)
print(labtech_single_stay, labtech_married_stay, labtech_divorced_stay)
print(labtech_single_leave, labtech_married_leave, labtech_divorced_leave)
print(labtech_stay, labtech_leave, labtech_total)
# Out:
# 88 116 55
# 57 97 43
# 31 19 12
# 197 62 259

# %%
manufdirector_single = len(df[(df['JobRole']=='Manufacturing Director') & (df['MaritalStatus']=='Single')])
manufdirector_married = len(df[(df['JobRole']=='Manufacturing Director') & (df['MaritalStatus']=='Married')])
manufdirector_divorced = len(df[(df['JobRole']=='Manufacturing Director') & (df['MaritalStatus']=='Divorced')])

manufdirector_single_stay = len(df[(df['JobRole']=='Manufacturing Director') & (df['MaritalStatus']=='Single') & (df['Attrition']=='No')])
manufdirector_married_stay = len(df[(df['JobRole']=='Manufacturing Director') & (df['MaritalStatus']=='Married') & (df['Attrition']=='No')])
manufdirector_divorced_stay = len(df[(df['JobRole']=='Manufacturing Director') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='No')])

manufdirector_single_leave = len(df[(df['JobRole']=='Manufacturing Director') & (df['MaritalStatus']=='Single') & (df['Attrition']=='Yes')])
manufdirector_married_leave = len(df[(df['JobRole']=='Manufacturing Director') & (df['MaritalStatus']=='Married') & (df['Attrition']=='Yes')])
manufdirector_divorced_leave = len(df[(df['JobRole']=='Manufacturing Director') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='Yes')])

manufdirector_stay = len(df[(df['JobRole']=='Manufacturing Director') & (df['Attrition']=='No')])
manufdirector_leave = len(df[(df['JobRole']=='Manufacturing Director') & (df['Attrition']=='Yes')])
manufdirector_total = len(df[(df['JobRole']=='Manufacturing Director')])


print(manufdirector_single, manufdirector_married, manufdirector_divorced)
print(manufdirector_single_stay, manufdirector_married_stay, manufdirector_divorced_stay)
print(manufdirector_single_leave, manufdirector_married_leave, manufdirector_divorced_leave)
print(manufdirector_stay, manufdirector_leave, manufdirector_total)
# Out:
# 42 67 36
# 39 61 35
# 3 6 1
# 135 10 145

# %%
researchdirector_single = len(df[(df['JobRole']=='Research Director') & (df['MaritalStatus']=='Single')])
researchdirector_married= len(df[(df['JobRole']=='Research Director') & (df['MaritalStatus']=='Married')])
researchdirector_divorced = len(df[(df['JobRole']=='Research Director') & (df['MaritalStatus']=='Divorced')])

researchdirector_single_stay = len(df[(df['JobRole']=='Research Director') & (df['MaritalStatus']=='Single') & (df['Attrition']=='No')])
researchdirector_married_stay= len(df[(df['JobRole']=='Research Director') & (df['MaritalStatus']=='Married') & (df['Attrition']=='No')])
researchdirector_divorced_stay = len(df[(df['JobRole']=='Research Director') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='No')])

researchdirector_single_leave = len(df[(df['JobRole']=='Research Director') & (df['MaritalStatus']=='Single') & (df['Attrition']=='Yes')])
researchdirector_married_leave= len(df[(df['JobRole']=='Research Director') & (df['MaritalStatus']=='Married') & (df['Attrition']=='Yes')])
researchdirector_divorced_leave = len(df[(df['JobRole']=='Research Director') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='Yes')])

researchdirector_stay = len(df[(df['JobRole']=='Research Director') & (df['Attrition']=='No')])
researchdirector_leave = len(df[(df['JobRole']=='Research Director') & (df['Attrition']=='Yes')])
researchdirector_total = len(df[(df['JobRole']=='Research Director')])


print(researchdirector_single, researchdirector_married, researchdirector_divorced)
print(researchdirector_single_stay, researchdirector_married_stay, researchdirector_divorced_stay)
print( researchdirector_single_leave, researchdirector_married_leave, researchdirector_divorced_leave)
print(researchdirector_stay, researchdirector_leave, researchdirector_total)
# Out:
# 19 38 23
# 18 37 23
# 1 1 0
# 78 2 80

# %%
researchsci_single = len(df[(df['JobRole']=='Research Scientist') & (df['MaritalStatus']=='Single')])
researchsci_married = len(df[(df['JobRole']=='Research Scientist') & (df['MaritalStatus']=='Married')])
researchsci_divorced = len(df[(df['JobRole']=='Research Scientist') & (df['MaritalStatus']=='Divorced')])

researchsci_single_stay = len(df[(df['JobRole']=='Research Scientist') & (df['MaritalStatus']=='Single') & (df['Attrition']=='No')])
researchsci_married_stay = len(df[(df['JobRole']=='Research Scientist') & (df['MaritalStatus']=='Married') & (df['Attrition']=='No')])
researchsci_divorced_stay = len(df[(df['JobRole']=='Research Scientist') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='No')])

researchsci_single_leave = len(df[(df['JobRole']=='Research Scientist') & (df['MaritalStatus']=='Single') & (df['Attrition']=='Yes')])
researchsci_married_leave = len(df[(df['JobRole']=='Research Scientist') & (df['MaritalStatus']=='Married') & (df['Attrition']=='Yes')])
researchsci_divorced_leave = len(df[(df['JobRole']=='Research Scientist') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='Yes')])

researchsci_stay = len(df[(df['JobRole']=='Research Scientist') & (df['Attrition']=='No')])
researchsci_leave = len(df[(df['JobRole']=='Research Scientist') & (df['Attrition']=='Yes')])
researchsci_total = len(df[(df['JobRole']=='Research Scientist')])


print(researchsci_single, researchsci_married, researchsci_divorced)
print(researchsci_single_stay, researchsci_married_stay, researchsci_divorced_stay)
print(researchsci_single_leave, researchsci_married_leave, researchsci_divorced_leave)
print(researchsci_stay, researchsci_leave, researchsci_total)
# Out:
# 108 122 62
# 79 108 58
# 29 14 4
# 245 47 292

# %%
salesexec_single = len(df[(df['JobRole']=='Sales Executive') & (df['MaritalStatus']=='Single')])
salesexec_married = len(df[(df['JobRole']=='Sales Executive') & (df['MaritalStatus']=='Married')])
salesexec_divorced = len(df[(df['JobRole']=='Sales Executive') & (df['MaritalStatus']=='Divorced')])

salesexec_single_stay = len(df[(df['JobRole']=='Sales Executive') & (df['MaritalStatus']=='Single') & (df['Attrition']=='No')])
salesexec_married_stay = len(df[(df['JobRole']=='Sales Executive') & (df['MaritalStatus']=='Married') & (df['Attrition']=='No')])
salesexec_divorced_stay = len(df[(df['JobRole']=='Sales Executive') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='No')])

salesexec_single_leave = len(df[(df['JobRole']=='Sales Executive') & (df['MaritalStatus']=='Single') & (df['Attrition']=='Yes')])
salesexec_married_leave = len(df[(df['JobRole']=='Sales Executive') & (df['MaritalStatus']=='Married') & (df['Attrition']=='Yes')])
salesexec_divorced_leave = len(df[(df['JobRole']=='Sales Executive') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='Yes')])

salesexec_stay = len(df[(df['JobRole']=='Sales Executive') & (df['Attrition']=='No')])
salesexec_leave = len(df[(df['JobRole']=='Sales Executive') & (df['Attrition']=='Yes')])
salesexec_total = len(df[(df['JobRole']=='Sales Executive')])


print(salesexec_single, salesexec_married, salesexec_divorced)
print(salesexec_single_stay, salesexec_married_stay, salesexec_divorced_stay)
print(salesexec_single_leave, salesexec_married_leave, salesexec_divorced_leave)
print(salesexec_stay, salesexec_leave, salesexec_total)
# Out:
# 106 151 69
# 75 131 63
# 31 20 6
# 269 57 326

# %%
salesrep_single = len(df[(df['JobRole']=='Sales Representative') & (df['MaritalStatus']=='Single')])
salesrep_married = len(df[(df['JobRole']=='Sales Representative') & (df['MaritalStatus']=='Married')])
salesrep_divorced = len(df[(df['JobRole']=='Sales Representative') & (df['MaritalStatus']=='Divorced')])

salesrep_single_stay = len(df[(df['JobRole']=='Sales Representative') & (df['MaritalStatus']=='Single') & (df['Attrition']=='No')])
salesrep_married_stay = len(df[(df['JobRole']=='Sales Representative') & (df['MaritalStatus']=='Married') & (df['Attrition']=='No')])
salesrep_divorced_stay = len(df[(df['JobRole']=='Sales Representative') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='No')])

salesrep_single_leave = len(df[(df['JobRole']=='Sales Representative') & (df['MaritalStatus']=='Single') & (df['Attrition']=='Yes')])
salesrep_married_leave = len(df[(df['JobRole']=='Sales Representative') & (df['MaritalStatus']=='Married') & (df['Attrition']=='Yes')])
salesrep_divorced_leave = len(df[(df['JobRole']=='Sales Representative') & (df['MaritalStatus']=='Divorced') & (df['Attrition']=='Yes')])

salesrep_stay = len(df[(df['JobRole']=='Sales Representative') & (df['Attrition']=='No')])
salesrep_leave = len(df[(df['JobRole']=='Sales Representative') & (df['Attrition']=='Yes')])
salesrep_total = len(df[(df['JobRole']=='Sales Representative')])


print(salesrep_single, salesrep_married, salesrep_divorced)
print(salesrep_single_stay, salesrep_married_stay, salesrep_divorced_stay)
print(salesrep_single_leave, salesrep_married_leave, salesrep_divorced_leave)
print(salesrep_stay, salesrep_leave, salesrep_total)
# Out:
# 38 34 11
# 17 26 7
# 21 8 4
# 50 33 83

# %%
x = ['Healthcare Representative', 'Human Resources', 'Laboratory Technician']
y1 = np.array([healthcarerep_single_stay, hr_single_stay, labtech_single_stay])
y2 = np.array([healthcarerep_married_stay, hr_married_stay, labtech_married_stay])
y3 = np.array([healthcarerep_divorced_stay, hr_divorced_stay, labtech_divorced_stay])
z1 = np.array([healthcarerep_single_leave, hr_single_leave, labtech_single_leave])

plt.bar(x, y1, color='r')
plt.bar(x, y2, bottom=y1, color='b')
plt.bar(x, y3, bottom=y1+y2, color='y')
plt.bar(x, z1, color='r' )

plt.xlabel("Job Role")
plt.ylabel("Number of Employees")
plt.legend(["Single", "Married", "Divorced"])
plt.title("Employee Marital Status by Job Role")

plt.show()

# %%
#x = np.arange(3)
#np.linspace
job_labels = ['Healthcare Representative', 'Human Resources', 'Laboratory Technician']
x = np.arange(len(job_labels))

y1 = np.array([healthcarerep_single_stay, hr_single_stay, labtech_single_stay])
y2 = np.array([healthcarerep_married_stay, hr_married_stay, labtech_married_stay])
y3 = np.array([healthcarerep_divorced_stay, hr_divorced_stay, labtech_divorced_stay])
z1 = np.array([healthcarerep_single_leave, hr_single_leave, labtech_single_leave])

width = 0.3

plt.bar(x+.15, y1, width, color='g')
plt.bar(x+.15, y2, width, bottom=y1, color='b')
plt.bar(x+.15, y3, width, bottom=y1+y2, color='r')
plt.bar(x-.15, z1, width, color='r' )

plt.xlabel("Job Role")
plt.ylabel("Number of Employees")
plt.legend(["Single", "Married", "Divorced"])
plt.title("Employee Marital Status by Job Role")

#xticks(np.arange(0, 2.1, step= 0.3))
#plt.xticks(np.arange(3), ['HC Rep', 'HR', 'Lab Tech'])
#plt.xticks(xticks = x, xticklabels = xticks)

#fig, ax = plt.subplots()
#ax.set_ylabel('Number of Employees')
#ax.set_title('Employee Marital Status by Job Role')
#ax.set_xticks( x + width, job_labels)


#xticks = ['Healthcare Representative', 'Human Resources', 'Laboratory Technician']
plt.xticks()

plt.show()

# %%
total_stay =len(df[(df['Attrition']=='No')])
total_leave =len(df[(df['Attrition']=='Yes')])

print(total_stay, total_leave)


slices = np.array([total_stay, total_leave])
mylabels = ["Employees Retained", "Employees Lost"]

plt.pie(slices, labels= mylabels, autopct= '%1.1f%%', startangle= 180)
plt.legend(loc= 'lower left', title = "Employee Attrition")
plt.show
# Out:
# 1233 237
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
jobsat = df['JobSatisfaction'].unique()
jobsat


jobsat1_leave =len(df[(df['Attrition']=='Yes') & (df['JobSatisfaction']== 1)])
jobsat2_leave =len(df[(df['Attrition']=='Yes') & (df['JobSatisfaction']== 2)])
jobsat3_leave =len(df[(df['Attrition']=='Yes') & (df['JobSatisfaction']== 3)])
jobsat4_leave =len(df[(df['Attrition']=='Yes') & (df['JobSatisfaction']== 4)])

print(jobsat1_leave, jobsat2_leave,jobsat3_leave, jobsat4_leave)


slices2 = np.array([jobsat1_leave, jobsat1_leave, jobsat3_leave, jobsat4_leave])
mylabels2 = ["1", "2", "3", "4"]

plt.pie(slices2, labels= mylabels2, autopct= '%1.1f%%', startangle= 180)
plt.title('Former Employee Job Satisfaction')
plt.show
# Out:
# 66 46 73 52
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#def addlabels(x,y1):
    #for i in range(len(x)):
        #plt.text(i, y1[i], y1[i], ha = 'center')

#if __name__=='__main__':
#labels = ['Healthcare Representative', 'Human Resources', 'Laboratory Technician', 'Manager', 'Manufacturing Director', 
     #'Research Director', 'Research Scientist', 'Sales Executive', 'Sales Representative']
#x = np.arange(len(labels))
x = ['HC Rep', 'HR', 'Lab Tech', 'Mngr', 'ManDir', 
     'ResDir', 'ResSci', 'SalExec', 'SalRep']
y1 = np.array([healthcarerep_single_leave, hr_single_leave, labtech_single_leave, manager_single_leave, manufdirector_single_leave,
               researchdirector_single_leave, researchsci_single_leave, salesexec_single_leave, salesrep_single_leave])
y2 = np.array([healthcarerep_married_leave, hr_married_leave, labtech_married_leave, manager_married_leave, manufdirector_married_leave,
               researchdirector_married_leave, researchsci_married_leave, salesexec_married_leave, salesrep_married_leave])
y3 = np.array([healthcarerep_divorced_leave, hr_divorced_leave, labtech_divorced_leave, manager_divorced_leave, manufdirector_divorced_leave,
               researchdirector_divorced_leave, researchsci_divorced_leave, salesexec_divorced_leave, salesrep_divorced_leave])



plt.bar(x, y1, color='r')
plt.bar(x, y2, bottom=y1, color='b')
plt.bar(x, y3, bottom=y1+y2, color='y')



plt.xlabel("Job Role")
plt.ylabel("Number of Employees")
plt.legend(["Single", "Married", "Divorced"])
plt.title("Former Employee Marital Status by Job Role")

#plt.xticks(x, rotation='vertical')

plt.figure(figsize=(30,3))

plt.show()

# %%
plt.scatter(x=df['Age'], y=df['YearsAtCompany'])
plt.xlabel('Age')
plt.ylabel('YearsAtCompany')
plt.title('Age of Employee vs. Years Worked at Company')
plt.show()

# %%
travel_frequently = df[df['BusinessTravel'] == 'Non-Travel'].count()
travel_frequently
# Out:
# Age                         150
# Attrition                   150
# BusinessTravel              150
# DailyRate                   150
# Department                  150
# DistanceFromHome            150
# Education                   150
# EducationField              150
# EmployeeCount               150
# EmployeeNumber              150
# EnvironmentSatisfaction     150
# Gender                      150
# HourlyRate                  150
# JobInvolvement              150
# JobLevel                    150
# JobRole                     150
# JobSatisfaction             150
# MaritalStatus               150
# MonthlyIncome               150
# MonthlyRate                 150
# NumCompaniesWorked          150
# Over18                      150
# OverTime                    150
# PercentSalaryHike           150
# PerformanceRating           150
# RelationshipSatisfaction    150
# StandardHours               150
# StockOptionLevel            150
# TotalWorkingYears           150
# ...

# %%
df2 = pd.DataFrame({
    'Business Travel': ['Travel_Frequently', 'Travel_Rarely', 'Non-Travel'],
    'Employees': [277, 1043, 150]
})
df2.plot(x='Business Travel', y='Employees', kind='bar')
# Out:
# <Axes: xlabel='Business Travel'>
